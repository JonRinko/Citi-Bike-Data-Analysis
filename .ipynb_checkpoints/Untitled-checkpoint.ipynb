# %%
# import dependencies
import pandas as pd
import psycopg2
import sqlalchemy
import numpy as np
import matplotlib as plt

# %matplotlib inline

# %%
# connect Postgres db 
from sqlalchemy import create_engine

# %%
# the username and pw is 'postgres'
engine = create_engine("postgresql://postgres:postgres@localhost:5432/CitiBike")
conn = engine.connect()

# %%
# test the conn with simple query
tables = pd.read_sql("SELECT * from information_schema.tables WHERE table_catalog = 'CitiBike' AND table_schema = 'public'", conn)
tables.head(50)
# Out:
#    table_catalog table_schema      table_name  table_type  \
# 0       CitiBike       public    january_2018  BASE TABLE
# 1       CitiBike       public        feb_2018  BASE TABLE
# 2       CitiBike       public      march_2018  BASE TABLE
# 3       CitiBike       public      april_2018  BASE TABLE
# 4       CitiBike       public        may_2018  BASE TABLE
# 5       CitiBike       public        may_2019  BASE TABLE
# 6       CitiBike       public      april_2019  BASE TABLE
# 7       CitiBike       public      march_2019  BASE TABLE
# 8       CitiBike       public        feb_2019  BASE TABLE
# 9       CitiBike       public    january_2019  BASE TABLE
# 10      CitiBike       public       june_2018  BASE TABLE
# 11      CitiBike       public       june_2019  BASE TABLE
# 12      CitiBike       public       july_2019  BASE TABLE
# 13      CitiBike       public       july_2018  BASE TABLE
# 14      CitiBike       public     august_2018  BASE TABLE
# ...

# %% [markdown]
# You will notice the tables have poor naming choices: instead of using a sortable name like 01_2018, I went with january_2018 and so on... don't make this mistake.

# %% [markdown]
# ### Combine the tables into a single table in postgres

# %% [markdown]
# This step assumes all (23) tables have been created with the necessary data types and they do not have a primary key
# Also the csv's have all been imported into postgres as well
# First we need to add a primary key because I did not do this yet
#
# ### The below code is done in pgadmin
#
# SELECT * FROM september_2019; --choose any table to copy the format
#
# CREATE TABLE cumulative AS TABLE september_2019 WITH NO DATA; --test that we now have a blank table with matching headers
#
# SELECT * FROM cumulative;
#
# -- primary key id add
#
# ALTER TABLE cumulative ADD COLUMN id SERIAL NOT NULL;
#
# ALTER TABLE cumulative ADD PRIMARY KEY (id);
